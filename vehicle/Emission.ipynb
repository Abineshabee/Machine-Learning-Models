# %%
import pandas as pd

data = pd.read_csv('vehicle/vehicle_emission_dataset.csv')

data
# Out:
#      Vehicle Type Fuel Type  Engine Size  Age of Vehicle  Mileage       Speed  \
# 0      Motorcycle  Electric     2.747609              22   291288   49.083255
# 1             Bus  Electric     5.743714               3   188398   23.460311
# 2             Bus    Hybrid     4.606368              17   281451  115.508350
# 3           Truck  Electric     3.913024               4   151321   18.540217
# 4           Truck    Hybrid     1.611297              15    91810  109.596566
# ...           ...       ...          ...             ...      ...         ...
# 9995   Motorcycle  Electric     5.259811               1    67323   60.526870
# 9996          Bus    Diesel     5.467046               5   252851  114.120190
# 9997          Bus    Petrol     5.722881               8    44810   11.987215
# 9998          Bus    Hybrid     2.866938               2    58719   95.832661
# 9999          Car    Petrol     1.929130              15   242020   40.137971
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Vehicle Type        10000 non-null  object
#  1   Fuel Type           10000 non-null  object
#  2   Engine Size         10000 non-null  float64
#  3   Age of Vehicle      10000 non-null  int64
#  4   Mileage             10000 non-null  int64
#  5   Speed               10000 non-null  float64
#  6   Acceleration        10000 non-null  float64
#  7   Road Type           10000 non-null  object
#  8   Traffic Conditions  10000 non-null  object
#  9   Temperature         10000 non-null  float64
#  10  Humidity            10000 non-null  float64
#  11  Wind Speed          10000 non-null  float64
#  12  Air Pressure        10000 non-null  float64
#  13  CO2 Emissions       10000 non-null  float64
#  14  NOx Emissions       10000 non-null  float64
# ...

# %%
data.shape
# Out:
# (10000, 19)

# %%
data.describe()
# Out:
#         Engine Size  Age of Vehicle        Mileage         Speed  \
# count  10000.000000    10000.000000   10000.000000  10000.000000
# mean       3.369630       14.490000  148995.708000     59.448818
# std        1.495677        8.584339   87068.385915     34.437175
# min        0.800061        0.000000      56.000000      0.000664
# 25%        2.080910        7.000000   73589.750000     29.502708
# 50%        3.361149       15.000000  148914.500000     59.701114
# 75%        4.648033       22.000000  224359.500000     88.499982
# max        5.998532       29.000000  299863.000000    119.974725
#
#        Acceleration   Temperature      Humidity    Wind Speed  Air Pressure  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       2.491924     14.935772     50.144758     10.027946   1000.199354
# std        1.446130     14.432900     28.787763      5.735533     28.789590
# ...

# %%
data.isnull()
# Out:
#       Vehicle Type  Fuel Type  Engine Size  Age of Vehicle  Mileage  Speed  \
# 0            False      False        False           False    False  False
# 1            False      False        False           False    False  False
# 2            False      False        False           False    False  False
# 3            False      False        False           False    False  False
# 4            False      False        False           False    False  False
# ...            ...        ...          ...             ...      ...    ...
# 9995         False      False        False           False    False  False
# 9996         False      False        False           False    False  False
# 9997         False      False        False           False    False  False
# 9998         False      False        False           False    False  False
# 9999         False      False        False           False    False  False
#
# ...

# %%
data.isnull().sum()
# Out:
# Vehicle Type          0
# Fuel Type             0
# Engine Size           0
# Age of Vehicle        0
# Mileage               0
# Speed                 0
# Acceleration          0
# Road Type             0
# Traffic Conditions    0
# Temperature           0
# Humidity              0
# Wind Speed            0
# Air Pressure          0
# CO2 Emissions         0
# NOx Emissions         0
# PM2.5 Emissions       0
# VOC Emissions         0
# SO2 Emissions         0
# Emission Level        0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the string categories to numerical labels
Vehicle_Type  = label_encoder.fit_transform( data['Vehicle Type'] )
Fuel_Type  = label_encoder.fit_transform( data['Fuel Type'] )
Road_Type  = label_encoder.fit_transform( data['Road Type'] )
Traffic_Conditions  = label_encoder.fit_transform( data['Traffic Conditions'] )
Emission_Level  = label_encoder.fit_transform( data['Emission Level'] )

# %%
data.columns
# Out:
# Index(['Vehicle Type', 'Fuel Type', 'Engine Size', 'Age of Vehicle', 'Mileage',
#        'Speed', 'Acceleration', 'Road Type', 'Traffic Conditions',
#        'Temperature', 'Humidity', 'Wind Speed', 'Air Pressure',
#        'CO2 Emissions', 'NOx Emissions', 'PM2.5 Emissions', 'VOC Emissions',
#        'SO2 Emissions', 'Emission Level'],
#       dtype='object')

# %%
Dataset = pd.DataFrame({

    'Vehicle Type'          : Vehicle_Type              , 
    'Fuel Type'             : Fuel_Type                 , 
    'Engine Size'           : data['Engine Size']       , 
    'Age of Vehicle'        : data['Age of Vehicle']    , 
    'Mileage'               : data['Mileage']           ,
    'Speed'                 : data['Speed']             , 
    'Acceleration'          : data['Acceleration']      , 
    'Road Type'             : Road_Type                 , 
    'Traffic Conditions'    : Traffic_Conditions        ,
    'Temperature'           : data['Temperature']       , 
    'Humidity'              : data['Humidity']          , 
    'Wind Speed'            : data['Wind Speed']        , 
    'Air Pressure'          : data['Air Pressure']      ,
    'CO2 Emissions'         : data['CO2 Emissions']     , 
    'NOx Emissions'         : data['NOx Emissions']     , 
    'PM2.5 Emissions'       : data['PM2.5 Emissions']   , 
    'VOC Emissions'         : data['VOC Emissions']     ,
    'SO2 Emissions'         : data['SO2 Emissions']     , 
    'Emission Level'        : Emission_Level      
    
})
Dataset
# Out:
#       Vehicle Type  Fuel Type  Engine Size  Age of Vehicle  Mileage  \
# 0                2          1     2.747609              22   291288
# 1                0          1     5.743714               3   188398
# 2                0          2     4.606368              17   281451
# 3                3          1     3.913024               4   151321
# 4                3          2     1.611297              15    91810
# ...            ...        ...          ...             ...      ...
# 9995             2          1     5.259811               1    67323
# 9996             0          0     5.467046               5   252851
# 9997             0          3     5.722881               8    44810
# 9998             0          2     2.866938               2    58719
# 9999             1          3     1.929130              15   242020
#
#            Speed  Acceleration  Road Type  Traffic Conditions  Temperature  \
# ...

# %%
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Vehicle Type        10000 non-null  int64
#  1   Fuel Type           10000 non-null  int64
#  2   Engine Size         10000 non-null  float64
#  3   Age of Vehicle      10000 non-null  int64
#  4   Mileage             10000 non-null  int64
#  5   Speed               10000 non-null  float64
#  6   Acceleration        10000 non-null  float64
#  7   Road Type           10000 non-null  int64
#  8   Traffic Conditions  10000 non-null  int64
#  9   Temperature         10000 non-null  float64
#  10  Humidity            10000 non-null  float64
#  11  Wind Speed          10000 non-null  float64
#  12  Air Pressure        10000 non-null  float64
#  13  CO2 Emissions       10000 non-null  float64
#  14  NOx Emissions       10000 non-null  float64
# ...

# %%
Dataset.shape
# Out:
# (10000, 19)

# %%
data.shape
# Out:
# (10000, 19)

# %%
X = pd.DataFrame( Dataset.drop( 'Emission Level' , axis = 1 ) )
y = pd.DataFrame( Dataset['Emission Level'])

# %%
X
# Out:
#       Vehicle Type  Fuel Type  Engine Size  Age of Vehicle  Mileage  \
# 0                2          1     2.747609              22   291288
# 1                0          1     5.743714               3   188398
# 2                0          2     4.606368              17   281451
# 3                3          1     3.913024               4   151321
# 4                3          2     1.611297              15    91810
# ...            ...        ...          ...             ...      ...
# 9995             2          1     5.259811               1    67323
# 9996             0          0     5.467046               5   252851
# 9997             0          3     5.722881               8    44810
# 9998             0          2     2.866938               2    58719
# 9999             1          3     1.929130              15   242020
#
#            Speed  Acceleration  Road Type  Traffic Conditions  Temperature  \
# ...

# %%
y
# Out:
#       Emission Level
# 0                  2
# 1                  2
# 2                  0
# 3                  0
# 4                  1
# ...              ...
# 9995               0
# 9996               1
# 9997               0
# 9998               2
# 9999               0
#
# [10000 rows x 1 columns]

# %%
print( X.shape )
print( y.shape )
# Out:
# (10000, 18)
# (10000, 1)

# %%
from sklearn.model_selection import train_test_split

# Perform the train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,  stratify = y  , random_state=2)

print( X_train.shape )
print( y_train.shape )
# Out:
# (7000, 18)
# (7000, 1)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

model = SVC(kernel='linear') 

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# /home/abinesh/py-run/lib/python3.12/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy: 0.99
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      1326
#            1       0.99      0.99      0.99       692
#            2       0.99      0.99      0.99       982
#
#     accuracy                           0.99      3000
#    macro avg       0.99      0.99      0.99      3000
# weighted avg       0.99      0.99      0.99      3000

# %%
index = 4

test =  Dataset.drop( 'Emission Level' , axis = 1 ).iloc[index]

result = Dataset.iloc[index]
print( f'Actual Result : { list(result)[-1] }' )

testout = model.predict( [ test ] )
print(f'Result        : {  testout  }')

if( testout[0] == 0 ) :
    print("Result        : High")
elif( testout[0] == 1 ):
    print("Result        : Low ")
else :
    print("Result        : Medium")
# Out:
# Actual Result : 1.0
# Result        : [1]
# Result        : Low
# /home/abinesh/py-run/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
