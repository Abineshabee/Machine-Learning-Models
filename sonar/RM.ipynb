# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#Load data
sonar_data = pd.read_csv('sonar_data.csv', header = None )

# %%
sonar_data.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# 3  0.0040  0.0117   R
# 4  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
#saparating Dataset

X = sonar_data.drop(columns = 60 , axis = 1)
Y = sonar_data[60]

# %%
#Training And Test Datasets

x_train , x_test , y_train , y_test = train_test_split( X , Y , test_size = 0.1 , stratify = Y , random_state = 1 )

# %%
#Data Shapes

print( X.shape , x_train.shape , x_test.shape )
print( Y.shape , y_train.shape , y_test.shape )
# Out:
# (208, 60) (187, 60) (21, 60)
# (208,) (187,) (21,)

# %%
#Model Creation And Training 

model = LogisticRegression()

model.fit( x_train , y_train )
# Out:
# LogisticRegression()

# %%
model_xtrain_prediction = model.predict( x_train )
model_xtrain_prediction_accuracy = accuracy_score( model_xtrain_prediction , y_train )

# %%
#Xtrain accuracy
print(model_xtrain_prediction_accuracy)
# Out:
# 0.8342245989304813

# %%
model_xtest_prediction = model.predict( x_test )
model_xtest_prediction_accuracy = accuracy_score( model_xtest_prediction , y_test )

# %%
#Xtest accuracy
print(model_xtest_prediction_accuracy)
# Out:
# 0.7619047619047619

# %%
#Predictive System

input_data = (0.0233,0.0394,0.0416,0.0547,0.0993,0.1515,0.1674,0.1513,0.1723,0.2078,0.1239,0.0236,0.1771,0.3115,0.4990,0.6707,0.7655,0.8485,0.9805,1.0000,1.0000,0.9992,0.9067,0.6803,0.5103,0.4716,0.4980,0.6196,0.7171,0.6316,0.3554,0.2897,0.4316,0.3791,0.2421,0.0944,0.0351,0.0844,0.0436,0.1130,0.2045,0.1937,0.0834,0.1502,0.1675,0.1058,0.1111,0.0849,0.0596,0.0201,0.0071,0.0104,0.0062,0.0026,0.0025,0.0061,0.0038,0.0101,0.0078,0.0006)

input_array = np.array(input_data)

#InputData ReShape

input_data_reshaped = input_array.reshape(1,-1)
print(input_data_reshaped)
# Out:
# [[2.330e-02 3.940e-02 4.160e-02 5.470e-02 9.930e-02 1.515e-01 1.674e-01
#   1.513e-01 1.723e-01 2.078e-01 1.239e-01 2.360e-02 1.771e-01 3.115e-01
#   4.990e-01 6.707e-01 7.655e-01 8.485e-01 9.805e-01 1.000e+00 1.000e+00
#   9.992e-01 9.067e-01 6.803e-01 5.103e-01 4.716e-01 4.980e-01 6.196e-01
#   7.171e-01 6.316e-01 3.554e-01 2.897e-01 4.316e-01 3.791e-01 2.421e-01
#   9.440e-02 3.510e-02 8.440e-02 4.360e-02 1.130e-01 2.045e-01 1.937e-01
#   8.340e-02 1.502e-01 1.675e-01 1.058e-01 1.111e-01 8.490e-02 5.960e-02
#   2.010e-02 7.100e-03 1.040e-02 6.200e-03 2.600e-03 2.500e-03 6.100e-03
#   3.800e-03 1.010e-02 7.800e-03 6.000e-04]]

# %%
prediction = model.predict( input_data_reshaped )

if ( prediction[0] == 'R' ) :
    print("Model_Prediction :  Rock ")
else :
    print("Model_Prediction : Mine ")
# Out:
# Model_Prediction : Mine
